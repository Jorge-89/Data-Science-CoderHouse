# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorge-89/Data-Science-CoderHouse/blob/main/Leer%20y%20manipular%20un%20JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio JSON & APIs

# %%
import requests
import json
import pandas as pd

# %%
url = "https://jsonplaceholder.typicode.com/users"
r = requests.get(url)
r.text
# Out:
# '[\n  {\n    "id": 1,\n    "name": "Leanne Graham",\n    "username": "Bret",\n    "email": "Sincere@april.biz",\n    "address": {\n      "street": "Kulas Light",\n      "suite": "Apt. 556",\n      "city": "Gwenborough",\n      "zipcode": "92998-3874",\n      "geo": {\n        "lat": "-37.3159",\n        "lng": "81.1496"\n      }\n    },\n    "phone": "1-770-736-8031 x56442",\n    "website": "hildegard.org",\n    "company": {\n      "name": "Romaguera-Crona",\n      "catchPhrase": "Multi-layered client-server neural-net",\n      "bs": "harness real-time e-markets"\n    }\n  },\n  {\n    "id": 2,\n    "name": "Ervin Howell",\n    "username": "Antonette",\n    "email": "Shanna@melissa.tv",\n    "address": {\n      "street": "Victor Plains",\n      "suite": "Suite 879",\n      "city": "Wisokyburgh",\n      "zipcode": "90566-7771",\n      "geo": {\n        "lat": "-43.9509",\n        "lng": "-34.4618"\n      }\n    },\n    "phone": "010-692-6593 x09125",\n    "website": "anastasia.net",\n
# ...

# %%
datos_json = json.loads(r.text)
df = pd.DataFrame.from_dict(datos_json)
df
# Out:
#    id  ...                                            company
# 0   1  ...  {'name': 'Romaguera-Crona', 'catchPhrase': 'Mu...
# 1   2  ...  {'name': 'Deckow-Crist', 'catchPhrase': 'Proac...
# 2   3  ...  {'name': 'Romaguera-Jacobson', 'catchPhrase': ...
# 3   4  ...  {'name': 'Robel-Corkery', 'catchPhrase': 'Mult...
# 4   5  ...  {'name': 'Keebler LLC', 'catchPhrase': 'User-c...
# 5   6  ...  {'name': 'Considine-Lockman', 'catchPhrase': '...
# 6   7  ...  {'name': 'Johns Group', 'catchPhrase': 'Config...
# 7   8  ...  {'name': 'Abernathy Group', 'catchPhrase': 'Im...
# 8   9  ...  {'name': 'Yost and Sons', 'catchPhrase': 'Swit...
# 9  10  ...  {'name': 'Hoeger LLC', 'catchPhrase': 'Central...
#
# [10 rows x 8 columns]

# %%
#Creamos 3 listas para introducir adentro los datos de los diccionarios address, geo,company
lista_address=[]
lista_geo=[]
lista_company=[]

for i in datos_json:
    lista_address.append(i["address"])
    lista_company.append(i["company"])
    
for a in lista:
    lista_geo.append(a["geo"])

# %%
#cada lista la transformo en un DataFrame
df_address = pd.DataFrame.from_dict(lista_address)
df_geo = pd.DataFrame.from_dict(lista_geo)
df_company = pd.DataFrame.from_dict(lista_company)
df_company=df_company.rename(columns={'name': 'nombre_compañia'}) #cambio el nombre de la columna name, ya que más adelante la usaremos para el join

# %%
df_unido = df.join(df_address).join(df_geo).join(df_company) #si no cambiaba name por nombre_compañia al hacer join daba error, ya que en el df original hay una columna llamada name
df_unido
# Out:
#    id  ...                                    bs
# 0   1  ...           harness real-time e-markets
# 1   2  ...      synergize scalable supply-chains
# 2   3  ...       e-enable strategic applications
# 3   4  ...  transition cutting-edge web services
# 4   5  ...      revolutionize end-to-end systems
# 5   6  ...      e-enable innovative applications
# 6   7  ...         generate enterprise e-tailers
# 7   8  ...         e-enable extensible e-tailers
# 8   9  ...      aggregate real-time technologies
# 9  10  ...              target end-to-end models
#
# [10 rows x 18 columns]

# %%
#una vez todo unido, elimino las columnas con diccionarios originales que ya no me sirven
df_unido.drop(['address',"geo", "company"], axis=1)
# Out:
#    id  ...                                    bs
# 0   1  ...           harness real-time e-markets
# 1   2  ...      synergize scalable supply-chains
# 2   3  ...       e-enable strategic applications
# 3   4  ...  transition cutting-edge web services
# 4   5  ...      revolutionize end-to-end systems
# 5   6  ...      e-enable innovative applications
# 6   7  ...         generate enterprise e-tailers
# 7   8  ...         e-enable extensible e-tailers
# 8   9  ...      aggregate real-time technologies
# 9  10  ...              target end-to-end models
#
# [10 rows x 15 columns]
